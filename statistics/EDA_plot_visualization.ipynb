# %% [markdown]
# ## Seaborn - Built on top of Matplotlib

# %%
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
fifa = pd.read_csv('data-for-datavis/fifa.csv')

# %%
fifa
# Out:
#            Date   ARG  BRA   ESP   FRA  GER   ITA
# 0    1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1    1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 2    1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 3    1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 4    1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ..          ...   ...  ...   ...   ...  ...   ...
# 281  2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 282  2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 283  2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 284  2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 285  2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 7 columns]

# %%
fifa['Date'].astype('datetime64[ns]')
# Out:
# 0     1993-08-08
# 1     1993-09-23
# 2     1993-10-22
# 3     1993-11-19
# 4     1993-12-23
#          ...
# 281   2018-02-15
# 282   2018-03-15
# 283   2018-04-12
# 284   2018-05-17
# 285   2018-06-07
# Name: Date, Length: 286, dtype: datetime64[ns]

# %%
fifa['Date'].astype('datetime64[ns]').dt.day_name()
# Out:
# 0        Sunday
# 1      Thursday
# 2        Friday
# 3        Friday
# 4      Thursday
#          ...
# 281    Thursday
# 282    Thursday
# 283    Thursday
# 284    Thursday
# 285    Thursday
# Name: Date, Length: 286, dtype: object

# %%
fifa = pd.read_csv('data-for-datavis/fifa.csv',index_col='Date',parse_dates=True)

# %%
fifa.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
sns.lineplot(data=fifa)
# Out:
# <Axes: xlabel='Date'>

# %%
plt.figure(figsize=(25,10))
sns.lineplot(data=fifa)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Steps
# #### 1. Load Data
# #### 2. Examine - EDA
# #### 3. Pre-process
# #### 4. Build a Model

# %%
spotify = pd.read_csv('data-for-datavis/spotify.csv')

# %%
spotify.isna().sum()
# Out:
# Date                         0
# Shape of You                 0
# Despacito                    7
# Something Just Like This    47
# HUMBLE.                     84
# Unforgettable               91
# dtype: int64

# %%
spotify
# Out:
#            Date  Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# 0    2017-01-06      12287078        NaN                       NaN        NaN
# 1    2017-01-07      13190270        NaN                       NaN        NaN
# 2    2017-01-08      13099919        NaN                       NaN        NaN
# 3    2017-01-09      14506351        NaN                       NaN        NaN
# 4    2017-01-10      14275628        NaN                       NaN        NaN
# ..          ...           ...        ...                       ...        ...
# 361  2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 362  2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 363  2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 364  2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 365  2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#      Unforgettable
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 361      2869783.0
# 362      2743748.0
# 363      2441045.0
# 364      2622693.0
# 365      2627334.0
#
# [366 rows x 6 columns]

# %%
spotify.head()
# Out:
#          Date  Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# 0  2017-01-06      12287078        NaN                       NaN      NaN
# 1  2017-01-07      13190270        NaN                       NaN      NaN
# 2  2017-01-08      13099919        NaN                       NaN      NaN
# 3  2017-01-09      14506351        NaN                       NaN      NaN
# 4  2017-01-10      14275628        NaN                       NaN      NaN
#
#    Unforgettable
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
spotify.tail()
# Out:
#            Date  Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# 361  2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 362  2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 363  2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 364  2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 365  2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#      Unforgettable
# 361      2869783.0
# 362      2743748.0
# 363      2441045.0
# 364      2622693.0
# 365      2627334.0

# %%
spotify = pd.read_csv('data-for-datavis/spotify.csv',index_col='Date',parse_dates=True)

# %%
spotify
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN        NaN
# 2017-01-07      13190270        NaN                       NaN        NaN
# 2017-01-08      13099919        NaN                       NaN        NaN
# 2017-01-09      14506351        NaN                       NaN        NaN
# 2017-01-10      14275628        NaN                       NaN        NaN
# ...                  ...        ...                       ...        ...
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN
# ...                   ...
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0
#
# [366 rows x 5 columns]

# %%
plt.figure(figsize=(25,10))
sns.lineplot(data=spotify)
# Out:
# <Axes: xlabel='Date'>

# %%
plt.figure(figsize=(25,10))
sns.lineplot(data=spotify)
plt.title("Popular song streams in Spotify from 2017 - 2018")
plt.xlabel("Dates from 2017 - 2018")
plt.ylabel("Streams")
# Out:
# Text(0, 0.5, 'Streams')

# %%
plt.figure(figsize=(25,10))
sns.lineplot(data=spotify['Shape of You'],label='Shape of You')
sns.lineplot(data=spotify['Despacito'],label='Despacito')
plt.title("Popular song streams in Spotify from 2017 - 2018")
plt.xlabel("Dates from 2017 - 2018")
plt.ylabel("Streams")
# Out:
# Text(0, 0.5, 'Streams')

# %%
plt.figure(figsize=(8,4))
sns.lineplot(data=spotify['Shape of You'],label='Shape of You')
plt.title("Popular song streams in Spotify from 2017 - 2018")
plt.xlabel("Dates from 2017 - 2018")
plt.ylabel("Streams")

plt.figure(figsize=(8,4))
sns.lineplot(data=spotify['Despacito'],label='Despacito')
plt.title("Popular song streams in Spotify from 2017 - 2018")
plt.xlabel("Dates from 2017 - 2018")
plt.ylabel("Streams")
# Out:
# Text(0, 0.5, 'Streams')

# %%
flightDelay = pd.read_csv('data-for-datavis/flight_delays.csv',index_col='Month')

# %%
flightDelay.head()
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#              HA         MQ         NK         OO        UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894  6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895  7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693  4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796  4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162  6.827695  0.681605
#
#              VX        WN
# Month
# 1      1.420702  3.389466
# 2      7.784410  3.501363
# 3      5.348207  3.263341
# 4      0.995507  2.996399
# 5      7.102021  5.680777

# %%
plt.figure(figsize=(16,6))
sns.barplot(x = flightDelay.index, y = flightDelay['AA'])
# Out:
# <Axes: xlabel='Month', ylabel='AA'>

# %%
plt.figure(figsize=(16,6))
sns.barplot(x = flightDelay.index, y = flightDelay['NK'])
# Out:
# <Axes: xlabel='Month', ylabel='NK'>

# %%
spotify = pd.read_csv('data-for-datavis/spotify.csv',index_col='Date',parse_dates=True)

# %%
spotify
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN        NaN
# 2017-01-07      13190270        NaN                       NaN        NaN
# 2017-01-08      13099919        NaN                       NaN        NaN
# 2017-01-09      14506351        NaN                       NaN        NaN
# 2017-01-10      14275628        NaN                       NaN        NaN
# ...                  ...        ...                       ...        ...
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN
# ...                   ...
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0
#
# [366 rows x 5 columns]

# %%
spotify.shape
# Out:
# (366, 5)

# %%
sns.set(style='darkgrid')
NA = spotify.isna().sum() / len(spotify)
NA = pd.DataFrame(NA,columns=['count'])
NA.index.names = ['Name']
sns.barplot(x = 'Name', y = 'count', data = NA)
plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Shape of You'),
#   Text(1, 0, 'Despacito'),
#   Text(2, 0, 'Something Just Like This'),
#   Text(3, 0, 'HUMBLE.'),
#   Text(4, 0, 'Unforgettable')])

# %%
sns.set(style='darkgrid')
NA = (spotify.isna().sum() / len(spotify))* 100
NA = pd.DataFrame(NA,columns=['Percentage % of missing values'])
NA.index.names = ['Name']
sns.barplot(x = 'Name', y = 'Percentage % of missing values', data = NA)
plt.title("Bar Chart")
plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Shape of You'),
#   Text(1, 0, 'Despacito'),
#   Text(2, 0, 'Something Just Like This'),
#   Text(3, 0, 'HUMBLE.'),
#   Text(4, 0, 'Unforgettable')])

# %%
NA.reset_index()
# Out:
#                        Name  Percentage % of missing values
# 0              Shape of You                        0.000000
# 1                 Despacito                        1.912568
# 2  Something Just Like This                       12.841530
# 3                   HUMBLE.                       22.950820
# 4             Unforgettable                       24.863388

# %%
sns.set(style='darkgrid')
NA = (spotify.isna().sum() / len(spotify))* 100
NA = pd.DataFrame(NA,columns=['Percentage % of missing values'])
NA.index.names = ['Name']
NA.reset_index(inplace=True)
sns.barplot(x = NA['Name'], y = NA['Percentage % of missing values'])
plt.title("Bar Chart")
plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Shape of You'),
#   Text(1, 0, 'Despacito'),
#   Text(2, 0, 'Something Just Like This'),
#   Text(3, 0, 'HUMBLE.'),
#   Text(4, 0, 'Unforgettable')])

# %%
sns.set(style='darkgrid')
NA = (spotify.isna().sum() / len(spotify))* 100
NA = pd.DataFrame(NA,columns=['Percentage % of missing values'])
NA.index.names = ['Name']
#NA.reset_index(inplace=True)
sns.barplot(x = NA.index, y = NA['Percentage % of missing values'])
plt.title("Bar Chart")
plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Shape of You'),
#   Text(1, 0, 'Despacito'),
#   Text(2, 0, 'Something Just Like This'),
#   Text(3, 0, 'HUMBLE.'),
#   Text(4, 0, 'Unforgettable')])

# %%
sns.set(style='whitegrid')
sns.set_palette("Paired")
NA = (spotify.isna().sum() / len(spotify))* 100
NA = pd.DataFrame(NA,columns=['Percentage % of missing values'])
NA.index.names = ['Name']
sns.barplot(x = 'Name', y = 'Percentage % of missing values', data=NA)
plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Shape of You'),
#   Text(1, 0, 'Despacito'),
#   Text(2, 0, 'Something Just Like This'),
#   Text(3, 0, 'HUMBLE.'),
#   Text(4, 0, 'Unforgettable')])

# %%
sns.set(style='whitegrid')
NA = (spotify.isna().sum() / len(spotify))* 100
NA = pd.DataFrame(NA,columns=['Percentage % of missing values'])
NA.index.names = ['Name']
sns.barplot(x = 'Name', y = 'Percentage % of missing values', data=NA, palette='viridis')
plt.xticks(rotation = 90)
# Out:
# C:\Users\heber\AppData\Local\Temp\ipykernel_7268\1260281053.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'Name', y = 'Percentage % of missing values', data=NA, palette='viridis')
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Shape of You'),
#   Text(1, 0, 'Despacito'),
#   Text(2, 0, 'Something Just Like This'),
#   Text(3, 0, 'HUMBLE.'),
#   Text(4, 0, 'Unforgettable')])

# %%
sns.set(style='whitegrid')
colors = ['red','blue','green','yellow','orange','purple','brown','black','pink','gray']
NA = (spotify.isna().sum() / len(spotify))* 100
NA = pd.DataFrame(NA,columns=['Percentage % of missing values'])
NA.index.names = ['Name']
sns.barplot(x = 'Name', y = 'Percentage % of missing values', data=NA, palette = colors)
plt.xticks(rotation = 90)
# Out:
# C:\Users\heber\AppData\Local\Temp\ipykernel_7268\1261806045.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'Name', y = 'Percentage % of missing values', data=NA, palette = colors)
# C:\Users\heber\AppData\Local\Temp\ipykernel_7268\1261806045.py:6: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.barplot(x = 'Name', y = 'Percentage % of missing values', data=NA, palette = colors)
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Shape of You'),
#   Text(1, 0, 'Despacito'),
#   Text(2, 0, 'Something Just Like This'),
#   Text(3, 0, 'HUMBLE.'),
#   Text(4, 0, 'Unforgettable')])

# %%
sns.set(style='whitegrid')
#colors = ['red','blue','green','yellow','orange','purple','brown','black','pink','gray']
NA = (spotify.isna().sum() / len(spotify))* 100
NA = pd.DataFrame(NA,columns=['Percentage % of missing values'])
NA.index.names = ['Name']
barplt = sns.barplot(x = 'Name', y = 'Percentage % of missing values', data=NA, palette = 'deep')
for bar in barplt.patches:
  barplt.annotate(format(bar.get_height(), '.2f'),(bar.get_x()+bar.getwidth()/2, bar.get_height()), ha='center', va='center', size=10, xytext=(0,8), textcoords='offset points')
plt.xticks(rotation = 90)
# Out:
# C:\Users\heber\AppData\Local\Temp\ipykernel_7268\1086783278.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplt = sns.barplot(x = 'Name', y = 'Percentage % of missing values', data=NA, palette = 'deep')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 8
#       6 barplt = sns.barplot(x = 'Name', y = 'Percentage % of missing values', data=NA, palette = 'deep')
#       7 for bar in barplt.patches:
# ----> 8   barplt.annotate(format(bar.get_height(), '.2f'),(bar.get_x()+bar.getwidth()/2, bar.get_height()), ha='center', va='center', size=10, xytext=(0,8), textcoords='offset points')
#       9 plt.xticks(rotation = 90)
#
# AttributeError: 'Rectangle' object has no attribute 'getwidth'

# %%
sns.set(style = 'whitegrid')
#sns.set_palette("pastel")
#colors = ['red', 'blue', 'green', 'purple']
NA = (spotify.isna().sum() / len(spotify))*100
NA = pd.DataFrame(NA, columns = ['Percentage % of missing values'])
NA.index.names = ['Name']
#NA.reset_index(inplace = True)
barplt = sns.barplot(x = "Name", y= 'Percentage % of missing values', data = NA, palette = 'deep')
for bar in barplt.patches:
  barplt.annotate(format(bar.get_height(),'.2f'),(bar.get_x()+bar.get_width()/2,bar.get_height()),ha = 'center', va = 'center', size = 10, xytext=(0,8), textcoords = "offset points")
plt.xticks(rotation = 90)
# Out:
# C:\Users\MT36\AppData\Local\Temp\ipykernel_4684\1356322694.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplt = sns.barplot(x = "Name", y= 'Percentage % of missing values', data = NA, palette = 'deep')
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Shape of You'),
#   Text(1, 0, 'Despacito'),
#   Text(2, 0, 'Something Just Like This'),
#   Text(3, 0, 'HUMBLE.'),
#   Text(4, 0, 'Unforgettable')])

# %%
flightDelay
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
#              HA         MQ         NK         OO         UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894   6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895   7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693   4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796   4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162   6.827695  0.681605
# 6      0.882786   9.639323  35.561501   8.338477  16.932663  5.766296
# 7      2.001586   3.980289  14.352382   6.790333  10.262551       NaN
# 8      7.448029   1.896565  20.519018   5.606689   5.014041       NaN
# 9      3.696915  -2.167268   8.000101   1.530896  -1.794265       NaN
# 10     0.467074  -3.735054   6.810736   1.750897  -2.456542       NaN
# 11    -2.719894   0.220061   7.543881   4.925548   0.281064       NaN
# 12    -1.706475   0.662486  12.733123  10.947612   7.012079       NaN
#
#               VX         WN
# Month
# 1       1.420702   3.389466
# 2       7.784410   3.501363
# 3       5.348207   3.263341
# 4       0.995507   2.996399
# 5       7.102021   5.680777
# 6       5.779415  10.743462
# 7       7.135773  10.504942
# 8       5.106221   5.532108
# 9       0.070998  -1.336260
# 10      2.254278  -0.688851
# 11      0.116370   0.995684
# 12     13.498720   6.720893

# %%
plt.figure(figsize = (10,6))
plt.title("Average Arrival Delyas for each of the flights, by Month")

corr = flightDelay.corr()
sns.heatmap(corr, vmin = -1, vmax = 1, center = 0, annot = True)
# Out:
# <Axes: title={'center': 'Average Arrival Delyas for each of the flights, by Month'}>

# %%
plt.figure(figsize = (10,6))
plt.title("Average Arrival Delyas for each of the flights, by Month")

corr = flightDelay.corr()
sns.heatmap(corr, vmin = -1, vmax = 1, center = 0)#annot = True) ==> Values will not populate
# Out:
# <Axes: title={'center': 'Average Arrival Delyas for each of the flights, by Month'}>

# %%
insurance = pd.read_csv('data-for-datavis/insurance.csv')

# %%
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.scatterplot(x = insurance['bmi'], y = insurance['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.scatterplot(x = insurance['sex'], y = insurance['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='smoker'>

# %%
sns.scatterplot(x = insurance['bmi'], y = insurance['charges'], hue = insurance['smoker'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.scatterplot(x = 'bmi', y = 'charges', hue = 'smoker', data = insurance)
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.lmplot(x = 'bmi', y = 'charges', hue = 'smoker', data = insurance)

# %%
sns.pairplot(insurance)
